# %% [markdown]
# # Open Images data preparation V2
#
# Copy of V1 notebook (01) (refining data preparation code even further).
#
# The goal of this notebook is to get the public Open Images data formatted in such a way it can be used with Detectron2.
#
# To download the Open Images, we're using the following script (modified):
# - https://github.com/spmallick/learnopencv/blob/master/downloadOpenImages/downloadOI.py
#
# We need to format the images downloaded using the script into Detectron2 style:
# - https://detectron2.readthedocs.io/tutorials/datasets.html
#
# Detectron2 example style:
# ```
# {'annotations': [{'bbox': [994, 619, 1445, 1166],
#    'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#    'category_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[1020.5,
#      963.5,
#      1000.5,
#      841.5,
# 		 ... #### Truncated ####
#      989.5,
#      1020.5,
#      963.5]]}],
#  'file_name': 'balloon/train/34020010494_e5cb88e1c4_k.jpg',
#  'height': 1536,
#  'image_id': 0,
#  'width': 2048}
# ```
#
# An example notebook using Detectron2 style inputs can be found here: https://colab.research.google.com/drive/16jcaJoc6bCFAQ96jDe2HwtXj7BMD_-m5
#
# We'll start by downloading a few sample images, then build a little script which converts the samples to Detectron2 style before ramping it up.

# %%
# # Install wget
# import sys
# !conda install --yes --prefix {sys.prefix} -c anaconda wget

# %%
# # Install OpenCV (cv2)
# import sys
# !conda install --yes --prefix {sys.prefix} -c conda-forge opencv

# %%
# Install tqdm & awscli
#!conda install --yes --prefix {sys.prefix} -c conda-forge tqdm awscli

# %%
# # Download required meta-files for V5 - https://storage.googleapis.com/openimages/web/download.html

# # Training bounding boxes (1.11G)
# !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv

# # Validating bounding boxes (23.94M)
# !wget https://storage.googleapis.com/openimages/v5/validation-annotations-bbox.csv
    
# # Testing bounding boxes (73.89M)
# !wget https://storage.googleapis.com/openimages/v5/test-annotations-bbox.csv

# # Class Names (11.73K)
# !wget https://storage.googleapis.com/openimages/v5/class-descriptions-boxable.csv

# %%
# Classes of amenities Airbnb mostly cares about
subset = ["Toilet",
          "Swimming_pool",
          "Bed",
          "Billiard_table",
          "Sink",
          "Fountain",
          "Oven",
          "Ceiling_fan",
          "Television",
          "Microwave_oven",
          "Gas_stove",
          "Refrigerator",
          "Kitchen_&_dining_room_table",
          "Washing_machine",
          "Bathtub",
          "Stairs",
          "Fireplace",
          "Pillow",
          "Mirror",
          "Shower",
          "Couch",
          "Countertop",
          "Coffeemaker",
          "Dishwasher",
          "Sofa_bed",
          "Tree_house",
          "Towel",
          "Porch",
          "Wine_rack",
          "Jacuzzi"]

# %%
# !python3 downloadOI.py --classes 'Bed' --dataset validation
# Out:
# Class 0 : Bed
# Class annotations 1: 03646bb2f288eaae,xclick,/m/03ssj5,1,0,0.9985229,0.22295806,0.9977925,1,1,0,0,0
# 0a6bc386b28f2aac,xclick,/m/03ssj5,1,0.182,0.716,0.536,0.928,0,0,0,0,0
# 0a6bc386b28f2aac,xclick,/m/03ssj5,1,0.376,0.99,0.59466666,1,0,0,0,0,0
# 0fb3a760f909c8c9,xclick,/m/03ssj5,1,0.28541666,0.99791664,0.48043817,0.9984351,1,1,0,0,0
# 1229d5e203956ac6,xclick,/m/03ssj5,1,0,0.3609375,0.18333334,0.775,0,1,0,0,0
# 1229d5e203956ac6,xclick,/m/03ssj5,1,0.63125,1,0.26875,0.9791667,0,0,0,0,0
# 15e9f230f8f0609f,xclick,/m/03ssj5,1,0,1,0.70625,1,0,1,0,0,0
# 17e05469444c8e0a,xclick,/m/03ssj5,1,0,1,0.21666667,1,0,1,0,0,0
# 18c8303c966a5ac6,xclick,/m/03ssj5,1,0,1,0.017699115,1,0,1,0,0,0
# 18ced18aee04c48e,xclick,/m/03ssj5,1,0,1,0,1,0,1,0,0,0
# 1d5bb9d9a8a49e84,xclick,/m/03ssj5,1,0,0.8421875,0.079166666,1,0,0,0,0,0
# 208e95b8f33fecda,xclick,/m/03ssj5,1,0,0.6233383,0.5629139,1,0,1,0,0,0
# 20af1d21449acdce,xclick,/m/03ssj5,1,0,0.4640625,0,0.48958334,1,1,0,0,0
# 2110e5d8ca7e5a99,xclick,/m/03ssj5,1,0,0.9984375,0,0.99791664,1,1,0,0,0
# 288150fcf6fcac88,xclick,/m/03ssj5,1,0.396875,1,0.3125,1,1,1,0,0,0
# 28a4c2b31f945e5f,xclick,/m/03ssj5,1,0.5097561,0.997561,0.5667276,0.9140768,1,0,0,0,0
# 2ac96d4eed4e33c8,xclick,/m/03ssj5,1,0.3578125,0.9984375,0.0020833334,0.66041666,0,1,0,0,0
# 2ed000d799794d71,xclick,/m/03ssj5,1,0,1,0.38412017,1,0,1,0,0,0
# 36fb4da1df30f769,xclick,/m/03ssj5,1,0,0.9983361,0,0.99607843,1,1,0,0,0
# 38f481601bac0d4a,xclick,/m/03ssj5,1,0,0.69264704,0.3436807,1,1,1,0,0,0
# 38f481601bac0d4a,xclick,/m/03ssj5,1,0.4779412,0.9044118,0.2949002,0.6895787,1,0,0,0,0
# 3a689e83e0e9f6e9,xclick,/m/03ssj5,1,0.39583334,1,0.6125,1,0,0,0,0,0
# 3bbc38b3beafe343,xclick,/m/03ssj5,1,0,0.7796875,0.38333333,0.99791664,0,1,0,0,0
# 3f65d9a5db068b25,xclick,/m/03ssj5,1,0.0015625,0.859375,0.14583333,1,0,1,0,0,0
# 3fb5e100e9962553,xclick,/m/03ssj5,1,0.39290586,1,0.52870816,1,0,0,0,0,0
# 408bfc9875660552,xclick,/m/03ssj5,1,0.15408805,0.7279874,0.6141079,1,0,0,0,0,0
# 409019c958741906,xclick,/m/03ssj5,1,0.15511551,0.6732673,0.54347825,0.96837944,0,0,0,0,0
# 4319a313fae699f9,xclick,/m/03ssj5,1,0,0.41875,0,1,0,1,0,0,0
# 4319a313fae699f9,xclick,/m/03ssj5,1,0.3015625,0.5453125,0.054166667,0.97291666,1,0,0,0,0
# 4319a313fae699f9,xclick,/m/03ssj5,1,0.4671875,1,0.0375,1,0,1,0,0,0
# 44e6ff6555a759f3,xclick,/m/03ssj5,1,0.08915663,0.97590363,0.38700947,0.65764546,0,0,0,0,0
# 4775ce4f3625482e,xclick,/m/03ssj5,1,0,0.91041666,0.63055557,1,0,1,0,0,0
# 477926ac3bcfb06e,xclick,/m/03ssj5,1,0.225,0.3671875,0.46041667,0.72083336,1,0,0,0,0
# 50123869e3d723f1,xclick,/m/03ssj5,1,0,1,0.033333335,1,0,1,0,0,0
# 50c91362e9bc580f,xclick,/m/03ssj5,1,0,1,0.016666668,1,0,1,0,0,1
# 5991aecc161bb5c8,xclick,/m/03ssj5,1,0,0.9955257,0.24489796,0.8206997,1,1,0,0,0
# 5a44d26db9ea0aa8,xclick,/m/03ssj5,1,0,0.99785864,0.12861736,0.9983923,0,1,0,0,0
# 5b906e188aac9f24,xclick,/m/03ssj5,1,0,0.77262694,0.42772862,0.53687316,0,1,0,0,0
# 5b906e188aac9f24,xclick,/m/03ssj5,1,0,0.777042,0.50884956,0.7699115,0,1,0,0,0
# 5e360c07411fb805,xclick,/m/03ssj5,1,0,0.8640625,0.45,0.99791664,1,0,0,0,0
# 5ebc104d9d7f872c,xclick,/m/03ssj5,1,0,1,0.004166667,0.99375,0,0,0,0,0
# 608fda8c976e0ac5,xclick,/m/03ssj5,1,0.028125,0.778125,0.31458333,1,1,1,0,0,0
# 608fda8c976e0ac5,xclick,/m/03ssj5,1,0.3,0.9515625,0.27916667,0.95,1,0,0,0,0
# 60fdb7fd333eaf74,xclick,/m/03ssj5,1,0.12195122,0.9376694,0.14457831,0.97590363,0,0,0,0,0
# 618dbeb8fb32291f,xclick,/m/03ssj5,1,0,1,0,1,0,1,0,0,0
# 63aae2fcaccefba7,xclick,/m/03ssj5,1,0.042424243,1,0.5573506,1,0,1,0,0,0
# 65a40656a6ba5344,xclick,/m/03ssj5,1,0,0.9985251,0.044247787,0.9977876,1,1,0,0,0
# 666a614b3123dff9,xclick,/m/03ssj5,1,0,0.60625,0.41041666,0.99791664,1,0,0,0,0
# 666a614b3123dff9,xclick,/m/03ssj5,1,0.4890625,0.9984375,0.37291667,1,1,0,0,0,0
# 68907defc0c961e1,xclick,/m/03ssj5,1,0,0.6125,0.44375,1,0,0,0,0,0
# 6c582f286b611dbb,xclick,/m/03ssj5,1,0,1,0.2,1,0,1,0,0,0
# 70a82a2501178f8b,xclick,/m/03ssj5,1,0,0.5,0.36041668,0.99791664,0,1,0,0,0
# 70a82a2501178f8b,xclick,/m/03ssj5,1,0.5875,0.9890625,0.33541667,0.99791664,1,1,0,0,0
# 711f4bda960e3983,xclick,/m/03ssj5,1,0,0.9977876,0.23451327,1,0,0,0,0,0
# 74c9a0c1ab44e47f,xclick,/m/03ssj5,1,0,1,0.5469314,1,0,0,0,0,0
# 755164cc12b2a690,xclick,/m/03ssj5,1,0,0.9640625,0.34791666,1,0,0,0,0,0
# 76c9df7686da333c,xclick,/m/03ssj5,1,0,0.998,0.3233831,0.99751246,0,1,0,0,0
# 7c125815652e330a,xclick,/m/03ssj5,1,0,1,0.11283186,1,0,0,0,0,0
# 7c3b876233adde13,xclick,/m/03ssj5,1,0,1,0.13053097,1,0,0,0,0,0
# 7d97e842bb3c1363,xclick,/m/03ssj5,1,0.01875,0.9890625,0.00625,0.99791664,0,0,0,0,0
# 87b1fa47c3ed5a92,xclick,/m/03ssj5,1,0.19411765,0.6602941,0.4767184,1,0,0,0,0,0
# 898890757a38a6db,xclick,/m/03ssj5,1,0.27794117,0.68088233,0.37915742,0.8203991,0,0,0,1,0
# 89ae6cceba0c6dc7,xclick,/m/03ssj5,1,0,0.8685446,0.40416667,0.99583334,1,1,0,0,0
# 8a01d74cbf72e782,xclick,/m/03ssj5,1,0.2109375,0.909375,0.6125,1,0,1,0,0,0
# 8afd2f0e67254343,xclick,/m/03ssj5,1,0.5524257,1,0.058333334,0.675,1,0,0,0,0
# 8d51d058a5f21775,xclick,/m/03ssj5,1,0.0015625,1,0.027083334,1,0,1,0,0,0
# 9295ab265fafd8e5,xclick,/m/03ssj5,1,0,0.96875,0.114583336,0.99791664,1,1,0,0,0
# 93641625fc063e6c,xclick,/m/03ssj5,1,0,0.6696165,0,1,0,1,0,0,0
# 968d0022f4b1d0dc,xclick,/m/03ssj5,1,0.49103138,0.84753364,0.5334302,1,0,0,0,0,0
# 96b573942e14da60,xclick,/m/03ssj5,1,0.36283186,1,0,1,0,1,0,0,0
# 96c539fa081cd474,xclick,/m/03ssj5,1,0,0.63274336,0,1,0,1,0,0,0
# 96c539fa081cd474,xclick,/m/03ssj5,1,0.71091443,0.9262537,0.17699115,1,1,1,0,0,0
# 980fb374c3ec75e3,xclick,/m/03ssj5,1,0.44035345,0.78350514,0.3761062,0.7234513,0,0,0,0,0
# 994385c9f33f2075,xclick,/m/03ssj5,1,0.0265625,0.9859375,0.73125,0.99791664,1,1,0,0,0
# 994385c9f33f2075,xclick,/m/03ssj5,1,0.0921875,0.359375,0.56041664,0.75,1,0,0,0,0
# 9afab31afacbba12,xclick,/m/03ssj5,1,0.79583335,0.94375,0.3828125,0.64375,1,1,0,0,0
# 9afab31afacbba12,xclick,/m/03ssj5,1,0.86875,1,0.334375,0.834375,0,1,0,0,0
# a0db623468bab8d5,xclick,/m/03ssj5,1,0.203125,0.7546875,0.31041667,0.91875,0,0,0,0,0
# a359ca53d4609faa,xclick,/m/03ssj5,1,0,0.996875,0.49583334,1,0,0,0,0,0
# a5d3b9952ef78c2e,xclick,/m/03ssj5,1,0.5046875,1,0.41041666,1,0,0,0,0,0
# a86c99772420c77e,xclick,/m/03ssj5,1,0.30686405,0.66890985,0.43583536,0.8958838,0,0,0,0,0
# a92113b2150cbc53,xclick,/m/03ssj5,1,0.057902973,0.90766823,0.022916667,1,0,0,0,0,0
# aa41ff683e2c5a60,xclick,/m/03ssj5,1,0.0020833334,0.64166665,0.275,1,0,1,0,0,0
# ab9b1e4579fd710b,xclick,/m/03ssj5,1,0.15151516,0.92424244,0.4631579,0.99473685,1,1,0,0,0
# b5f7b2aa13abe836,xclick,/m/03ssj5,1,0,0.8592058,0.2797834,0.99458486,1,0,0,0,0
# b613c149d79da0d2,xclick,/m/03ssj5,1,0,0.4234375,0.40416667,1,0,1,0,0,0
# b613c149d79da0d2,xclick,/m/03ssj5,1,0.2296875,0.8171875,0.35833332,0.98541665,0,0,0,0,0
# b613c149d79da0d2,xclick,/m/03ssj5,1,0.584375,1,0.33125,0.71875,0,0,0,0,0
# b6f26c9d7c6667c5,xclick,/m/03ssj5,1,0,1,0.20625,1,0,0,0,0,0
# b833ff7e8c121fd4,xclick,/m/03ssj5,1,0.3109375,0.95625,0.37916666,1,0,0,0,0,0
# bce01b280e7be3c9,xclick,/m/03ssj5,1,0,0.80625,0.54791665,1,1,1,0,0,0
# c08da8484c808dbe,xclick,/m/03ssj5,1,0.6386431,0.7787611,0.5685841,0.63274336,0,0,0,0,0
# c2b9ea7fa6acb336,xclick,/m/03ssj5,1,0.07782672,0.4743025,0.6607539,1,0,0,0,0,0
# c2b9ea7fa6acb336,xclick,/m/03ssj5,1,0.40381792,0.5315712,0.44124168,0.6696231,1,0,0,0,0
# c2ed6ddf764b96d4,xclick,/m/03ssj5,1,0.121875,1,0.65,1,0,1,0,0,0
# c3287d9a3da51af3,xclick,/m/03ssj5,1,0.18611522,1,0.50110376,1,0,1,0,0,0
# c4f2aabceda78470,xclick,/m/03ssj5,1,0,1,0.1768953,1,0,0,0,0,0
# c508797245ca5106,xclick,/m/03ssj5,1,0.18125,0.9921875,0.32916668,1,0,1,0,0,0
# c8dd79406a936789,xclick,/m/03ssj5,1,0.14345992,0.34810126,0.61051005,0.7434312,1,0,0,0,0
# cbc8443a05cf29cc,xclick,/m/03ssj5,1,0.1171875,0.775,0.68333334,1,0,1,0,0,0
# cd2ded9ae21c7f0e,xclick,/m/03ssj5,1,0.27286136,0.84070796,0.40486726,1,0,0,0,0,0
# ce442e81fded4107,xclick,/m/03ssj5,1,0.056047197,0.68289083,0.2920354,1,0,0,0,0,0
# d02bee6224ca943a,xclick,/m/03ssj5,1,0.19375,0.7953125,0.40938166,0.6076759,0,0,0,0,0
# d0e26d6efd457fc8,xclick,/m/03ssj5,1,0.4577573,0.9984639,0.33545646,0.9978769,1,1,0,0,0
# d794d9f52414c141,xclick,/m/03ssj5,1,0,1,0.48541668,1,0,0,0,0,0
# ddd8b588942ceded,xclick,/m/03ssj5,1,0.080763586,0.54772395,0.45454547,0.9955654,1,1,0,0,0
# dea2fdb1a77ec6bb,xclick,/m/03ssj5,1,0.22827688,0.7864507,0.40044248,0.9977876,0,0,0,0,0
# dea2fdb1a77ec6bb,xclick,/m/03ssj5,1,0.4388807,0.9381443,0.40044248,0.9380531,1,0,0,0,0
# e2089d2390b6031c,xclick,/m/03ssj5,1,0.14126395,0.94919455,0.010526316,1,0,0,0,0,0
# e3d0e1cc6109fa71,xclick,/m/03ssj5,1,0.012635379,0.49458483,0.71299636,0.9783394,0,1,0,0,0
# e3d0e1cc6109fa71,xclick,/m/03ssj5,1,0.014440433,0.49097472,0.1534296,0.49458483,0,1,0,0,0
# e3d0e1cc6109fa71,xclick,/m/03ssj5,1,0.50361013,0.98194945,0.18050541,0.49097472,0,1,0,0,0
# e3d0e1cc6109fa71,xclick,/m/03ssj5,1,0.5072202,0.9855596,0.69133574,0.98736465,0,1,0,0,0
# e7fe54073a9a84bc,xclick,/m/03ssj5,1,0,1,0.4532925,1,0,1,0,0,0
# e83c957123f20a19,xclick,/m/03ssj5,1,0.034285713,0.94857144,0.23428571,1,0,0,0,0,0
# eb959eb331e1d4ca,xclick,/m/03ssj5,1,0.24941176,0.75529414,0.5017544,1,1,0,0,0,0
# ee57bbfb0ebab0a7,xclick,/m/03ssj5,1,0.0453125,0.6609375,0.32708332,0.9875,1,1,0,0,0
# ee57bbfb0ebab0a7,xclick,/m/03ssj5,1,0.48125,1,0.33125,0.99583334,0,1,0,0,0
# ee57bbfb0ebab0a7,xclick,/m/03ssj5,1,0.70625,1,0.3625,0.99583334,0,1,0,0,0
# ef87eba394783972,xclick,/m/03ssj5,1,0.0014749262,0.8141593,0.35840708,0.9977876,1,1,0,0,0
# f2fa3f3c444148f2,xclick,/m/03ssj5,1,0,1,0,1,0,1,0,0,0
# f312f2af6e9a8073,xclick,/m/03ssj5,1,0,1,0.14073072,1,0,0,0,0,0
# f6b18f69ec5b4f5c,xclick,/m/03ssj5,1,0.65625,1,0.71458334,1,0,1,0,0,0
# fa8d6d40dac333ea,xclick,/m/03ssj5,1,0.22895126,0.6410635,0.34437087,0.9977925,0,0,0,0,0
# fa8d6d40dac333ea,xclick,/m/03ssj5,1,0.65583456,0.7872969,0.22295806,1,0,1,0,0,0
#
# Class annotations 2: ['03646bb2f288eaae,xclick,/m/03ssj5,1,0,0.9985229,0.22295806,0.9977925,1,1,0,0,0', '0a6bc386b28f2aac,xclick,/m/03ssj5,1,0.182,0.716,0.536,0.928,0,0,0,0,0', '0a6bc386b28f2aac,xclick,/m/03ssj5,1,0.376,0.99,0.59466666,1,0,0,0,0,0', '0fb3a760f909c8c9,xclick,/m/03ssj5,1,0.28541666,0.99791664,0.48043817,0.9984351,1,1,0,0,0', '1229d5e203956ac6,xclick,/m/03ssj5,1,0,0.3609375,0.18333334,0.775,0,1,0,0,0', '1229d5e203956ac6,xclick,/m/03ssj5,1,0.63125,1,0.26875,0.9791667,0,0,0,0,0', '15e9f230f8f0609f,xclick,/m/03ssj5,1,0,1,0.70625,1,0,1,0,0,0', '17e05469444c8e0a,xclick,/m/03ssj5,1,0,1,0.21666667,1,0,1,0,0,0', '18c8303c966a5ac6,xclick,/m/03ssj5,1,0,1,0.017699115,1,0,1,0,0,0', '18ced18aee04c48e,xclick,/m/03ssj5,1,0,1,0,1,0,1,0,0,0', '1d5bb9d9a8a49e84,xclick,/m/03ssj5,1,0,0.8421875,0.079166666,1,0,0,0,0,0', '208e95b8f33fecda,xclick,/m/03ssj5,1,0,0.6233383,0.5629139,1,0,1,0,0,0', '20af1d21449acdce,xclick,/m/03ssj5,1,0,0.4640625,0,0.48958334,1,1,0,0,0', '2110e5d8ca7e5a99,xclick,/m/03ssj5,1,0,0.9984375,0,0.99791664,1,1,0,0,0', '288150fcf6fcac88,xclick,/m/03ssj5,1,0.396875,1,0.3125,1,1,1,0,0,0', '28a4c2b31f945e5f,xclick,/m/03ssj5,1,0.5097561,0.997561,0.5667276,0.9140768,1,0,0,0,0', '2ac96d4eed4e33c8,xclick,/m/03ssj5,1,0.3578125,0.9984375,0.0020833334,0.66041666,0,1,0,0,0', '2ed000d799794d71,xclick,/m/03ssj5,1,0,1,0.38412017,1,0,1,0,0,0', '36fb4da1df30f769,xclick,/m/03ssj5,1,0,0.9983361,0,0.99607843,1,1,0,0,0', '38f481601bac0d4a,xclick,/m/03ssj5,1,0,0.69264704,0.3436807,1,1,1,0,0,0', '38f481601bac0d4a,xclick,/m/03ssj5,1,0.4779412,0.9044118,0.2949002,0.6895787,1,0,0,0,0', '3a689e83e0e9f6e9,xclick,/m/03ssj5,1,0.39583334,1,0.6125,1,0,0,0,0,0', '3bbc38b3beafe343,xclick,/m/03ssj5,1,0,0.7796875,0.38333333,0.99791664,0,1,0,0,0', '3f65d9a5db068b25,xclick,/m/03ssj5,1,0.0015625,0.859375,0.14583333,1,0,1,0,0,0', '3fb5e100e9962553,xclick,/m/03ssj5,1,0.39290586,1,0.52870816,1,0,0,0,0,0', '408bfc9875660552,xclick,/m/03ssj5,1,0.15408805,0.7279874,0.6141079,1,0,0,0,0,0', '409019c958741906,xclick,/m/03ssj5,1,0.15511551,0.6732673,0.54347825,0.96837944,0,0,0,0,0', '4319a313fae699f9,xclick,/m/03ssj5,1,0,0.41875,0,1,0,1,0,0,0', '4319a313fae699f9,xclick,/m/03ssj5,1,0.3015625,0.5453125,0.054166667,0.97291666,1,0,0,0,0', '4319a313fae699f9,xclick,/m/03ssj5,1,0.4671875,1,0.0375,1,0,1,0,0,0', '44e6ff6555a759f3,xclick,/m/03ssj5,1,0.08915663,0.97590363,0.38700947,0.65764546,0,0,0,0,0', '4775ce4f3625482e,xclick,/m/03ssj5,1,0,0.91041666,0.63055557,1,0,1,0,0,0', '477926ac3bcfb06e,xclick,/m/03ssj5,1,0.225,0.3671875,0.46041667,0.72083336,1,0,0,0,0', '50123869e3d723f1,xclick,/m/03ssj5,1,0,1,0.033333335,1,0,1,0,0,0', '50c91362e9bc580f,xclick,/m/03ssj5,1,0,1,0.016666668,1,0,1,0,0,1', '5991aecc161bb5c8,xclick,/m/03ssj5,1,0,0.9955257,0.24489796,0.8206997,1,1,0,0,0', '5a44d26db9ea0aa8,xclick,/m/03ssj5,1,0,0.99785864,0.12861736,0.9983923,0,1,0,0,0', '5b906e188aac9f24,xclick,/m/03ssj5,1,0,0.77262694,0.42772862,0.53687316,0,1,0,0,0', '5b906e188aac9f24,xclick,/m/03ssj5,1,0,0.777042,0.50884956,0.7699115,0,1,0,0,0', '5e360c07411fb805,xclick,/m/03ssj5,1,0,0.8640625,0.45,0.99791664,1,0,0,0,0', '5ebc104d9d7f872c,xclick,/m/03ssj5,1,0,1,0.004166667,0.99375,0,0,0,0,0', '608fda8c976e0ac5,xclick,/m/03ssj5,1,0.028125,0.778125,0.31458333,1,1,1,0,0,0', '608fda8c976e0ac5,xclick,/m/03ssj5,1,0.3,0.9515625,0.27916667,0.95,1,0,0,0,0', '60fdb7fd333eaf74,xclick,/m/03ssj5,1,0.12195122,0.9376694,0.14457831,0.97590363,0,0,0,0,0', '618dbeb8fb32291f,xclick,/m/03ssj5,1,0,1,0,1,0,1,0,0,0', '63aae2fcaccefba7,xclick,/m/03ssj5,1,0.042424243,1,0.5573506,1,0,1,0,0,0', '65a40656a6ba5344,xclick,/m/03ssj5,1,0,0.9985251,0.044247787,0.9977876,1,1,0,0,0', '666a614b3123dff9,xclick,/m/03ssj5,1,0,0.60625,0.41041666,0.99791664,1,0,0,0,0', '666a614b3123dff9,xclick,/m/03ssj5,1,0.4890625,0.9984375,0.37291667,1,1,0,0,0,0', '68907defc0c961e1,xclick,/m/03ssj5,1,0,0.6125,0.44375,1,0,0,0,0,0', '6c582f286b611dbb,xclick,/m/03ssj5,1,0,1,0.2,1,0,1,0,0,0', '70a82a2501178f8b,xclick,/m/03ssj5,1,0,0.5,0.36041668,0.99791664,0, ...
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/03646bb2f288eaae.jpg validation/03646bb2f288eaae.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/0a6bc386b28f2aac.jpg validation/0a6bc386b28f2aac.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/0a6bc386b28f2aac.jpg validation/0a6bc386b28f2aac.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/0fb3a760f909c8c9.jpg validation/0fb3a760f909c8c9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/1229d5e203956ac6.jpg validation/1229d5e203956ac6.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/1229d5e203956ac6.jpg validation/1229d5e203956ac6.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/15e9f230f8f0609f.jpg validation/15e9f230f8f0609f.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/17e05469444c8e0a.jpg validation/17e05469444c8e0a.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/18c8303c966a5ac6.jpg validation/18c8303c966a5ac6.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/18ced18aee04c48e.jpg validation/18ced18aee04c48e.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/1d5bb9d9a8a49e84.jpg validation/1d5bb9d9a8a49e84.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/208e95b8f33fecda.jpg validation/208e95b8f33fecda.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/20af1d21449acdce.jpg validation/20af1d21449acdce.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/2110e5d8ca7e5a99.jpg validation/2110e5d8ca7e5a99.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/288150fcf6fcac88.jpg validation/288150fcf6fcac88.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/28a4c2b31f945e5f.jpg validation/28a4c2b31f945e5f.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/2ac96d4eed4e33c8.jpg validation/2ac96d4eed4e33c8.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/2ed000d799794d71.jpg validation/2ed000d799794d71.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/36fb4da1df30f769.jpg validation/36fb4da1df30f769.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/38f481601bac0d4a.jpg validation/38f481601bac0d4a.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/38f481601bac0d4a.jpg validation/38f481601bac0d4a.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/3a689e83e0e9f6e9.jpg validation/3a689e83e0e9f6e9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/3bbc38b3beafe343.jpg validation/3bbc38b3beafe343.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/3f65d9a5db068b25.jpg validation/3f65d9a5db068b25.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/3fb5e100e9962553.jpg validation/3fb5e100e9962553.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/408bfc9875660552.jpg validation/408bfc9875660552.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/409019c958741906.jpg validation/409019c958741906.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/4319a313fae699f9.jpg validation/4319a313fae699f9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/4319a313fae699f9.jpg validation/4319a313fae699f9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/4319a313fae699f9.jpg validation/4319a313fae699f9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/44e6ff6555a759f3.jpg validation/44e6ff6555a759f3.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/4775ce4f3625482e.jpg validation/4775ce4f3625482e.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/477926ac3bcfb06e.jpg validation/477926ac3bcfb06e.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/50123869e3d723f1.jpg validation/50123869e3d723f1.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/50c91362e9bc580f.jpg validation/50c91362e9bc580f.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/5991aecc161bb5c8.jpg validation/5991aecc161bb5c8.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/5a44d26db9ea0aa8.jpg validation/5a44d26db9ea0aa8.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/5b906e188aac9f24.jpg validation/5b906e188aac9f24.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/5b906e188aac9f24.jpg validation/5b906e188aac9f24.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/5e360c07411fb805.jpg validation/5e360c07411fb805.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/5ebc104d9d7f872c.jpg validation/5ebc104d9d7f872c.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/608fda8c976e0ac5.jpg validation/608fda8c976e0ac5.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/608fda8c976e0ac5.jpg validation/608fda8c976e0ac5.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/60fdb7fd333eaf74.jpg validation/60fdb7fd333eaf74.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/618dbeb8fb32291f.jpg validation/618dbeb8fb32291f.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/63aae2fcaccefba7.jpg validation/63aae2fcaccefba7.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/65a40656a6ba5344.jpg validation/65a40656a6ba5344.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/666a614b3123dff9.jpg validation/666a614b3123dff9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/666a614b3123dff9.jpg validation/666a614b3123dff9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/68907defc0c961e1.jpg validation/68907defc0c961e1.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/6c582f286b611dbb.jpg validation/6c582f286b611dbb.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/70a82a2501178f8b.jpg validation/70a82a2501178f8b.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/70a82a2501178f8b.jpg validation/70a82a2501178f8b.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/711f4bda960e3983.jpg validation/711f4bda960e3983.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/74c9a0c1ab44e47f.jpg validation/74c9a0c1ab44e47f.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/755164cc12b2a690.jpg validation/755164cc12b2a690.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/76c9df7686da333c.jpg validation/76c9df7686da333c.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/7c125815652e330a.jpg validation/7c125815652e330a.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/7c3b876233adde13.jpg validation/7c3b876233adde13.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/7d97e842bb3c1363.jpg validation/7d97e842bb3c1363.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/87b1fa47c3ed5a92.jpg validation/87b1fa47c3ed5a92.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/898890757a38a6db.jpg validation/898890757a38a6db.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/89ae6cceba0c6dc7.jpg validation/89ae6cceba0c6dc7.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/8a01d74cbf72e782.jpg validation/8a01d74cbf72e782.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/8afd2f0e67254343.jpg validation/8afd2f0e67254343.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/8d51d058a5f21775.jpg validation/8d51d058a5f21775.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/9295ab265fafd8e5.jpg validation/9295ab265fafd8e5.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/93641625fc063e6c.jpg validation/93641625fc063e6c.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/968d0022f4b1d0dc.jpg validation/968d0022f4b1d0dc.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/96b573942e14da60.jpg validation/96b573942e14da60.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/96c539fa081cd474.jpg validation/96c539fa081cd474.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/96c539fa081cd474.jpg validation/96c539fa081cd474.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/980fb374c3ec75e3.jpg validation/980fb374c3ec75e3.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/994385c9f33f2075.jpg validation/994385c9f33f2075.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/994385c9f33f2075.jpg validation/994385c9f33f2075.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/9afab31afacbba12.jpg validation/9afab31afacbba12.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/9afab31afacbba12.jpg validation/9afab31afacbba12.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/a0db623468bab8d5.jpg validation/a0db623468bab8d5.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/a359ca53d4609faa.jpg validation/a359ca53d4609faa.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/a5d3b9952ef78c2e.jpg validation/a5d3b9952ef78c2e.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/a86c99772420c77e.jpg validation/a86c99772420c77e.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/a92113b2150cbc53.jpg validation/a92113b2150cbc53.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/aa41ff683e2c5a60.jpg validation/aa41ff683e2c5a60.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/ab9b1e4579fd710b.jpg validation/ab9b1e4579fd710b.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/b5f7b2aa13abe836.jpg validation/b5f7b2aa13abe836.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/b613c149d79da0d2.jpg validation/b613c149d79da0d2.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/b613c149d79da0d2.jpg validation/b613c149d79da0d2.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/b613c149d79da0d2.jpg validation/b613c149d79da0d2.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/b6f26c9d7c6667c5.jpg validation/b6f26c9d7c6667c5.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/b833ff7e8c121fd4.jpg validation/b833ff7e8c121fd4.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/bce01b280e7be3c9.jpg validation/bce01b280e7be3c9.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c08da8484c808dbe.jpg validation/c08da8484c808dbe.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c2b9ea7fa6acb336.jpg validation/c2b9ea7fa6acb336.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c2b9ea7fa6acb336.jpg validation/c2b9ea7fa6acb336.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c2ed6ddf764b96d4.jpg validation/c2ed6ddf764b96d4.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c3287d9a3da51af3.jpg validation/c3287d9a3da51af3.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c4f2aabceda78470.jpg validation/c4f2aabceda78470.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c508797245ca5106.jpg validation/c508797245ca5106.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/c8dd79406a936789.jpg validation/c8dd79406a936789.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/cbc8443a05cf29cc.jpg validation/cbc8443a05cf29cc.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/cd2ded9ae21c7f0e.jpg validation/cd2ded9ae21c7f0e.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/ce442e81fded4107.jpg validation/ce442e81fded4107.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/d02bee6224ca943a.jpg validation/d02bee6224ca943a.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/d0e26d6efd457fc8.jpg validation/d0e26d6efd457fc8.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/d794d9f52414c141.jpg validation/d794d9f52414c141.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/ddd8b588942ceded.jpg validation/ddd8b588942ceded.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/dea2fdb1a77ec6bb.jpg validation/dea2fdb1a77ec6bb.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/dea2fdb1a77ec6bb.jpg validation/dea2fdb1a77ec6bb.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/e2089d2390b6031c.jpg validation/e2089d2390b6031c.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/e3d0e1cc6109fa71.jpg validation/e3d0e1cc6109fa71.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/e3d0e1cc6109fa71.jpg validation/e3d0e1cc6109fa71.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/e3d0e1cc6109fa71.jpg validation/e3d0e1cc6109fa71.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/e3d0e1cc6109fa71.jpg validation/e3d0e1cc6109fa71.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/e7fe54073a9a84bc.jpg validation/e7fe54073a9a84bc.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/e83c957123f20a19.jpg validation/e83c957123f20a19.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/eb959eb331e1d4ca.jpg validation/eb959eb331e1d4ca.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/ee57bbfb0ebab0a7.jpg validation/ee57bbfb0ebab0a7.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/ee57bbfb0ebab0a7.jpg validation/ee57bbfb0ebab0a7.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/ee57bbfb0ebab0a7.jpg validation/ee57bbfb0ebab0a7.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/ef87eba394783972.jpg validation/ef87eba394783972.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/f2fa3f3c444148f2.jpg validation/f2fa3f3c444148f2.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/f312f2af6e9a8073.jpg validation/f312f2af6e9a8073.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/f6b18f69ec5b4f5c.jpg validation/f6b18f69ec5b4f5c.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/fa8d6d40dac333ea.jpg validation/fa8d6d40dac333ea.jpg
# Command 2: aws s3 --no-sign-request --only-show-errors cp s3://open-images-dataset/validation/fa8d6d40dac333ea.jpg validation/fa8d6d40dac333ea.jpg
# Downloading: 103 images | Num classes: 1 | Dataset: validation
# 100%|█████████████████████████████████████████| 103/103 [01:38<00:00,  1.05it/s]

# %%
# Turn subset of target classes into a long string for the command line
subset_string = str()
for i in subset:
    subset_string += str(i) + ","
subset_string
# Out:
# 'Toilet,Swimming_pool,Bed,Billiard_table,Sink,Fountain,Oven,Ceiling_fan,Television,Microwave_oven,Gas_stove,Refrigerator,Kitchen_&_dining_room_table,Washing_machine,Bathtub,Stairs,Fireplace,Pillow,Mirror,Shower,Couch,Countertop,Coffeemaker,Dishwasher,Sofa_bed,Tree_house,Towel,Porch,Wine_rack,Jacuzzi,'

# %% [markdown]
# ## Try download all the target images
#
# I'm going to now try and download all the target images (subset of classes) from the Open Images validation set.
#
# It would be good to have a function which downloaded strictly images of a certain class based on a list.
#
# Then created the labels later... that would save me from manipulating all the images I download with `downloadOI.py`...

# %%
# !python3 downloadOI.py --classes 'Toilet,Swimming_pool,Bed,Billiard_table,Sink,Fountain,Oven,Ceiling_fan,Television,Microwave_oven,Gas_stove,Refrigerator,Kitchen_&_dining_room_table,Washing_machine,Bathtub,Stairs,Fireplace,Pillow,Mirror,Shower,Couch,Countertop,Coffeemaker,Dishwasher,Sofa_bed,Tree_house,Towel,Porch,Wine_rack,Jacuzzi' --mode validation

# %% [markdown]
# ## Converting images/labels to Detectron2 style
# Now I've got images ready, my goal is to now convert their current style them into Detectron2 style (see below).
#
# I'll need a way to:
# 1. Traverse different file paths
# 2. Gather filenames and explore their text contents
# 3. Seek duplicates and make sure they contain multiple labels
#
# What I should end up with is:
# - A single file of images (can convert this to train/test later)
# - A dictionary of all of the different parameters for each image path
#     - Perhaps I could do this with a Pandas dataframe? So it's visual? Then convert it to JSON maybe?

# %%
detectron2_style = {
   'annotations': [{'bbox': [994, 619, 1445, 1166],
   'bbox_mode': "BoxMode.XYXY_ABS", ## NOTE: this isn't a string in the actual label
   'category_id': 0,
   'iscrowd': 0,
   'segmentation': [[1020.5,
     963.5,
     1000.5,
     841.5,
     #### Truncated ####
     989.5,
     1020.5,
     963.5]]}],
 'file_name': 'balloon/train/34020010494_e5cb88e1c4_k.jpg',
 'height': 1536,
 'image_id': 0,
 'width': 2048
}

# %% [markdown]
# ## Get Image ID's
#
# # TODO - check to see if all image ID's are unique (remove duplicates)

# %%
def get_image_ids(image_folder=None):
    """
    Explores a folder of images and gets their ID from their file name.
    Returns a list of all image ID's in image_folder.
    E.g. image_folder/608fda8c976e0ac.jpg -> ["608fda8c976e0ac"]
    
    Params
    ------
    image_folder (str): path to folder of images, e.g. "../validation/"
    """
    return [os.path.splitext(img_name)[0] for img_name in os.listdir(image_folder)]

# %%
val_image_ids = get_image_ids("validation")
val_image_ids[:10]
# Out:
# ['d0e26d6efd457fc8',
#  '608fda8c976e0ac5',
#  '898890757a38a6db',
#  'ab9b1e4579fd710b',
#  '3fb5e100e9962553',
#  '5e360c07411fb805',
#  '50c91362e9bc580f',
#  '408bfc9875660552',
#  'eb959eb331e1d4ca',
#  '8a01d74cbf72e782']

# %%
len(val_image_ids)
# Out:
# 103

# %% [markdown]
# ## Manipulate annotations based on the images we're using
#
# I should write a function which:
# - Gets my image IDs
# - Matches them with their details in the annotations csv
# - Updates the annotations csv based on the unique images we're using

# %%
# Make a function which formats a specific annotations csv based on what we're dealing with
def format_annotations(image_folder, annotation_file):
    """
    TODO - NOTE: This function could (definitely can) be faster.
    TODO - Some ideas: skip the use of pandas entirely and use CSV's
    
    Formats annotation_file based on images contained in image_folder.
    Will get all unique image IDs and make sure annotation_file
    only contains those (the target images).
    Adds meta-data to annotation_file such as class names and categories.
    Note: image_folder and annotation_file should both be validation if working on
    validation set or both be training if working on training set.
    
    Params
    ------
    image_folder (str): path to folder of target images.
    annotation_file (str): path to annotation file of target images.
    """
    # Get all image ids from target directory
    image_ids = get_image_ids(image_folder)
    
    # Setup annotation file and classnames
    annot_file = pd.read_csv(annotation_file)
    classes = pd.read_csv("class-descriptions-boxable.csv",
                          names=["LabelName", "ClassName"])
    
    # Create classname column on annotations which converts label codes to string labels
    annot_file["ClassName"] = annot_file["LabelName"].map(classes.set_index("LabelName")["ClassName"])
    
    # Make sure we only get the images we're concerned about
    annot_file = annot_file[annot_file["ImageID"].isin(image_ids)]
   
    # Add ClassID column, e.g. "Bathtub, Toilet" -> 1, 2
    annot_file["ClassID"] = pd.Categorical(annot_file["ClassName"]).codes
    
    return annot_file

# %%
# %%time
val_annot = format_annotations("validation", "validation-annotations-bbox.csv")
val_annot.head()
# Out:
# CPU times: user 580 ms, sys: 139 ms, total: 718 ms
# Wall time: 843 ms
#                 ImageID  Source  LabelName  Confidence   XMin      XMax  \
# 4220   03646bb2f288eaae  xclick  /m/0bt9lr           1  0.000  0.595273
# 4221   03646bb2f288eaae  xclick   /m/09j2d           1  0.000  0.723781
# 4222   03646bb2f288eaae  xclick  /m/03ssj5           1  0.000  0.998523
# 12322  0a6bc386b28f2aac  xclick  /m/01mzpv           1  0.282  0.410000
# 12323  0a6bc386b28f2aac  xclick   /m/0c_jw           1  0.184  0.998000
#
#            YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 4220   0.198676  0.662252           0            1          0            0
# 4221   0.233996  0.635762           0            1          0            0
# 4222   0.222958  0.997792           1            1          0            0
# 12322  0.405333  0.632000           1            0          0            0
# 12323  0.498667  1.000000           0            0          0            0
#
#        IsInside  ClassName  ClassID
# 4220          0        Dog       17
# 4221          0   Clothing       10
# 4222          0        Bed        1
# 12322         0      Chair        7
# 12323         0  Furniture       24

# %% [markdown]
# ## Start creating dataset dictionaries (how Detectron2 takes inputs)

# %%
# Import CV2 for getting height & width of image
import cv2

# %%
# Next: functionise the below code
def get_image_dicts(image_folder, annotations):
    """
    Returns Detectron2 style labels of images in image_folder based on data in annotations.
    
    TODO -- Maybe create some verbosity here? AKA, what are the outputs?
    TODO -- what if annotations = None? Can we create a call to create an annotations CSV in 1 hit?
    
    Params
    ------
    image_folder (str): target folder containing images
    annotations (DataFrame): DataFrame of image label data
    """
    # Get all unique image ids from target folder
    img_ids = get_image_ids(image_folder)
    
    # Start creating image dictionaries (Detectron2 style labelling)
    img_dicts = []
    for img in img_ids:
        record = {}
        
        # Get image metadata
        file_name = image_folder + "/" + img + ".jpg"
        height, width = cv2.imread(file_name).shape[:2]
        img_data = annotations[annotations["ImageID"] == img].reset_index() # reset index important for images
                                                                            # with multiple objects
        # Update record dictionary
        record["file_name"] = file_name
        record["image_id"] = img
        record["height"] = height
        record["width"] = width
        
        # Create list of image annotations (labels)
        img_annotations = []
        for i in range(len(img_data)): # this is where we loop through examples with multiple objects in an image
            category_id = img_data.loc[i]["ClassID"]
            # Get bounding box coordinates in Detectron2 style (x0, y0, x1, y1)
            bbox = [img_data.loc[i][["XMin", "YMin", "XMax", "YMax"]].values]
            # Setup annot (1 annot = 1 label, there might be more) dictionary
            annot = {
                "bbox": bbox,
                "bbox_mode": 0, # TODO - Will be: https://detectron2.readthedocs.io/modules/structures.html#detectron2.structures.BoxMode.XYXY_REL
                "category_id": category_id
            }
            img_annotations.append(annot)
            
        # Update record dictionary with annotations
        record["annotations"] = img_annotations
        
        # Add record dictionary with image annotations to img_dicts list
        img_dicts.append(record)
    return img_dicts

# %%
# %%time
val_img_dicts = get_image_dicts("validation", val_annot)
len(val_img_dicts)
# Out:
# CPU times: user 3.74 s, sys: 153 ms, total: 3.9 s
# Wall time: 5.09 s
# 103

# %%
# Check labels for random image
# TODO - make this visual
import random
number = round(random.randint(0, len(val_img_dicts)))
print(number)
val_img_dicts[number]
# Out:
# 55
# {'file_name': 'validation/18c8303c966a5ac6.jpg',
#  'image_id': '18c8303c966a5ac6',
#  'height': 1024,
#  'width': 682,
#  'annotations': [{'bbox': [array([0.0, 0.064896755, 0.5243363, 0.37020648], dtype=object)],
#    'bbox_mode': 0,
#    'category_id': 51},
#   {'bbox': [array([0.23451327, 0.036873157999999996, 0.75884956, 0.33038348],
#           dtype=object)],
#    'bbox_mode': 0,
#    'category_id': 51},
#   {'bbox': [array([0.47787609999999997, 0.053097345, 1.0, 0.35103244], dtype=object)],
#    'bbox_mode': 0,
#    'category_id': 51},
#   {'bbox': [array([0.0, 0.017699115, 1.0, 1.0], dtype=object)],
#    'bbox_mode': 0,
#    'category_id': 1}]}

# %% [markdown]
# Detectron2 example style:
# ```
# {'annotations': [{'bbox': [994, 619, 1445, 1166],
#    'bbox_mode': <BoxMode.XYXY_ABS: 0>,
#    'category_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[1020.5,
#      963.5,
#      1000.5,
#      841.5,
# 		 ... #### Truncated ####
#      989.5,
#      1020.5,
#      963.5]]}],
#  'file_name': 'balloon/train/34020010494_e5cb88e1c4_k.jpg',
#  'height': 1536,
#  'image_id': 0,
#  'width': 2048}
# ```

# %% [markdown]
# ## TODO - View an annotated image
#
# Now I've got a way to generate labels, I should be visualizing them as much as I can to make sure they're correct.

# %%
from IPython.display import Image
Image("images/5ba65f801a71d6b7.jpg")

# %% [markdown]
# # TK: Could I turn this into a script? Instead of it being in a notebook?

# %%
import csv
with open("validation-annotations-bbox.csv") as file:
    reader = csv.reader(file)   
reader
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-71c69f9da2a3> in <module>
#       3     reader = csv.reader(file)
#       4
# ----> 5 reader[0]
#
# TypeError: '_csv.reader' object is not subscriptable

# %%
import csv
with open("class-descriptions-boxable.csv") as file:
    reader = csv.reader(file)
    dict_list = {row[1]:row[0] for row in reader}
dict_list
# Out:
# {'Tortoise': '/m/011k07',
#  'Container': '/m/011q46kg',
#  'Magpie': '/m/012074',
#  'Sea turtle': '/m/0120dh',
#  'Football': '/m/01226z',
#  'Ambulance': '/m/012n7d',
#  'Ladder': '/m/012w5l',
#  'Toothbrush': '/m/012xff',
#  'Syringe': '/m/012ysf',
#  'Sink': '/m/0130jx',
#  'Toy': '/m/0138tl',
#  'Organ': '/m/013y1f',
#  'Cassette deck': '/m/01432t',
#  'Apple': '/m/014j1m',
#  'Human eye': '/m/014sv8',
#  'Cosmetics': '/m/014trl',
#  'Paddle': '/m/014y4n',
#  'Snowman': '/m/0152hh',
#  'Beer': '/m/01599',
#  'Chopsticks': '/m/01_5g',
#  'Human beard': '/m/015h_t',
#  'Bird': '/m/015p6',
#  'Parking meter': '/m/015qbp',
#  'Traffic light': '/m/015qff',
#  'Croissant': '/m/015wgc',
#  'Cucumber': '/m/015x4r',
#  'Radish': '/m/015x5n',
#  'Towel': '/m/0162_1',
#  'Doll': '/m/0167gd',
#  'Skull': '/m/016m2d',
#  'Washing machine': '/m/0174k2',
#  'Glove': '/m/0174n1',
#  'Tick': '/m/0175cv',
#  'Belt': '/m/0176mf',
#  'Sunglasses': '/m/017ftj',
#  'Banjo': '/m/018j2',
#  'Cart': '/m/018p4k',
#  'Ball': '/m/018xm',
#  'Backpack': '/m/01940j',
#  'Bicycle': '/m/0199g',
#  'Home appliance': '/m/019dx1',
#  'Centipede': '/m/019h78',
#  'Boat': '/m/019jd',
#  'Surfboard': '/m/019w40',
#  'Boot': '/m/01b638',
#  'Headphones': '/m/01b7fy',
#  'Hot dog': '/m/01b9xk',
#  'Shorts': '/m/01bfm9',
#  'Fast food': '/m/01_bhs',
#  'Bus': '/m/01bjv',
#  'Boy': '/m/01bl7v',
#  'Screwdriver': '/m/01bms0',
#  'Bicycle wheel': '/m/01bqk0',
#  'Barge': '/m/01btn',
#  'Laptop': '/m/01c648',
#  'Miniskirt': '/m/01cmb2',
#  'Drill': '/m/01d380',
#  'Dress': '/m/01d40f',
#  'Bear': '/m/01dws',
#  'Waffle': '/m/01dwsz',
#  'Pancake': '/m/01dwwc',
#  'Brown bear': '/m/01dxs',
#  'Woodpecker': '/m/01dy8n',
#  'Blue jay': '/m/01f8m5',
#  'Pretzel': '/m/01f91_',
#  'Bagel': '/m/01fb_0',
#  'Tower': '/m/01fdzj',
#  'Teapot': '/m/01fh4r',
#  'Person': '/m/01g317',
#  'Bow and arrow': '/m/01g3x7',
#  'Swimwear': '/m/01gkx_',
#  'Beehive': '/m/01gllr',
#  'Brassiere': '/m/01gmv2',
#  'Bee': '/m/01h3n',
#  'Bat': '/m/01h44',
#  'Starfish': '/m/01h8tj',
#  'Popcorn': '/m/01hrv5',
#  'Burrito': '/m/01j3zr',
#  'Chainsaw': '/m/01j4z9',
#  'Balloon': '/m/01j51',
#  'Wrench': '/m/01j5ks',
#  'Tent': '/m/01j61q',
#  'Vehicle registration plate': '/m/01jfm_',
#  'Lantern': '/m/01jfsr',
#  'Toaster': '/m/01k6s3',
#  'Flashlight': '/m/01kb5b',
#  'Billboard': '/m/01knjb',
#  'Tiara': '/m/01krhy',
#  'Limousine': '/m/01lcw4',
#  'Necklace': '/m/01llwg',
#  'Carnivore': '/m/01lrl',
#  'Scissors': '/m/01lsmm',
#  'Stairs': '/m/01lynh',
#  'Computer keyboard': '/m/01m2v',
#  'Printer': '/m/01m4t',
#  'Traffic sign': '/m/01mqdt',
#  'Chair': '/m/01mzpv',
#  'Shirt': '/m/01n4qj',
#  'Poster': '/m/01n5jq',
#  'Cheese': '/m/01nkt',
#  'Sock': '/m/01nq26',
#  'Fire hydrant': '/m/01pns0',
#  'Land vehicle': '/m/01prls',
#  'Earrings': '/m/01r546',
#  'Tie': '/m/01rkbr',
#  'Watercraft': '/m/01rzcn',
#  'Cabinetry': '/m/01s105',
#  'Suitcase': '/m/01s55n',
#  'Muffin': '/m/01tcjp',
#  'Bidet': '/m/01vbnl',
#  'Snack': '/m/01ww8y',
#  'Snowmobile': '/m/01x3jk',
#  'Clock': '/m/01x3z',
#  'Medical equipment': '/m/01xgg_',
#  'Cattle': '/m/01xq0k1',
#  'Cello': '/m/01xqw',
#  'Jet ski': '/m/01xs3r',
#  'Camel': '/m/01x_v',
#  'Coat': '/m/01xygc',
#  'Suit': '/m/01xyhv',
#  'Desk': '/m/01y9k5',
#  'Cat': '/m/01yrx',
#  'Bronze sculpture': '/m/01yx86',
#  'Juice': '/m/01z1kdw',
#  'Gondola': '/m/02068x',
#  'Beetle': '/m/020jm',
#  'Cannon': '/m/020kz',
#  'Computer mouse': '/m/020lf',
#  'Cookie': '/m/021mn',
#  'Office building': '/m/021sj1',
#  'Fountain': '/m/0220r2',
#  'Coin': '/m/0242l',
#  'Calculator': '/m/024d2',
#  'Cocktail': '/m/024g6',
#  'Computer monitor': '/m/02522',
#  'Box': '/m/025dyy',
#  'Stapler': '/m/025fsf',
#  'Christmas tree': '/m/025nd',
#  'Cowboy hat': '/m/025rp__',
#  'Hiking equipment': '/m/0268lbt',
#  'Studio couch': '/m/026qbn5',
#  'Drum': '/m/026t6',
#  'Dessert': '/m/0270h',
#  'Wine rack': '/m/0271qf7',
#  'Drink': '/m/0271t',
#  'Zucchini': '/m/027pcv',
#  'Ladle': '/m/027rl48',
#  'Human mouth': '/m/0283dt1',
#  'Dairy': '/m/0284d',
#  'Dice': '/m/029b3',
#  'Oven': '/m/029bxz',
#  'Dinosaur': '/m/029tx',
#  'Ratchet': '/m/02bm9n',
#  'Couch': '/m/02crq1',
#  'Cricket ball': '/m/02ctlc',
#  'Winter melon': '/m/02cvgx',
#  'Spatula': '/m/02d1br',
#  'Whiteboard': '/m/02d9qx',
#  'Pencil sharpener': '/m/02ddwp',
#  'Door': '/m/02dgv',
#  'Hat': '/m/02dl1y',
#  'Shower': '/m/02f9f_',
#  'Eraser': '/m/02fh7f',
#  'Fedora': '/m/02fq_6',
#  'Guacamole': '/m/02g30s',
#  'Dagger': '/m/02gzp',
#  'Scarf': '/m/02h19r',
#  'Dolphin': '/m/02hj4',
#  'Sombrero': '/m/02jfl0',
#  'Tin can': '/m/02jnhm',
#  'Mug': '/m/02jvh9',
#  'Tap': '/m/02jz0l',
#  'Harbor seal': '/m/02l8p9',
#  'Stretcher': '/m/02lbcq',
#  'Can opener': '/m/02mqfb',
#  'Goggles': '/m/02_n6y',
#  'Human body': '/m/02p0tk3',
#  'Roller skates': '/m/02p3w7d',
#  'Coffee cup': '/m/02p5f1q',
#  'Cutting board': '/m/02pdsw',
#  'Blender': '/m/02pjr4',
#  'Plumbing fixture': '/m/02pkr5',
#  'Stop sign': '/m/02pv19',
#  'Office supplies': '/m/02rdsp',
#  'Volleyball': '/m/02rgn06',
#  'Vase': '/m/02s195',
#  'Slow cooker': '/m/02tsc9',
#  'Wardrobe': '/m/02vkqh8',
#  'Coffee': '/m/02vqfm',
#  'Whisk': '/m/02vwcm',
#  'Paper towel': '/m/02w3r3',
#  'Personal care': '/m/02w3_ws',
#  'Food': '/m/02wbm',
#  'Sun hat': '/m/02wbtzl',
#  'Tree house': '/m/02wg_p',
#  'Flying disc': '/m/02wmf',
#  'Skirt': '/m/02wv6h6',
#  'Gas stove': '/m/02wv84t',
#  'Salt and pepper shakers': '/m/02x8cch',
#  'Mechanical fan': '/m/02x984l',
#  'Face powder': '/m/02xb7qb',
#  'Fax': '/m/02xqq',
#  'Fruit': '/m/02xwb',
#  'French fries': '/m/02y6n',
#  'Nightstand': '/m/02z51p',
#  'Barrel': '/m/02zn6n',
#  'Kite': '/m/02zt3',
#  'Tart': '/m/02zvsm',
#  'Treadmill': '/m/030610',
#  'Fox': '/m/0306r',
#  'Flag': '/m/03120',
#  'Horn': '/m/0319l',
#  'Window blind': '/m/031b6r',
#  'Human foot': '/m/031n1',
#  'Golf cart': '/m/0323sq',
#  'Jacket': '/m/032b3c',
#  'Egg': '/m/033cnk',
#  'Street light': '/m/033rq4',
#  'Guitar': '/m/0342h',
#  'Pillow': '/m/034c16',
#  'Human leg': '/m/035r7c',
#  'Isopod': '/m/035vxb',
#  'Grape': '/m/0388q',
#  'Human ear': '/m/039xj_',
#  'Power plugs and sockets': '/m/03bbps',
#  'Panda': '/m/03bj1',
#  'Giraffe': '/m/03bk1',
#  'Woman': '/m/03bt1vf',
#  'Door handle': '/m/03c7gz',
#  'Rhinoceros': '/m/03d443',
#  'Bathtub': '/m/03dnzn',
#  'Goldfish': '/m/03fj2',
#  'Houseplant': '/m/03fp41',
#  'Goat': '/m/03fwl',
#  'Baseball bat': '/m/03g8mr',
#  'Baseball glove': '/m/03grzl',
#  'Mixing bowl': '/m/03hj559',
#  'Marine invertebrates': '/m/03hl4l9',
#  'Kitchen utensil': '/m/03hlz0c',
#  'Light switch': '/m/03jbxj',
#  'House': '/m/03jm5',
#  'Horse': '/m/03k3r',
#  'Stationary bicycle': '/m/03kt2w',
#  'Hammer': '/m/03l9g',
#  'Ceiling fan': '/m/03ldnb',
#  'Sofa bed': '/m/03m3pdh',
#  'Adhesive tape': '/m/03m3vtv',
#  'Harp': '/m/03m5k',
#  'Sandal': '/m/03nfch',
#  'Bicycle helmet': '/m/03p3bw',
#  'Saucer': '/m/03q5c7',
#  'Harpsichord': '/m/03q5t',
#  'Human hair': '/m/03q69',
#  'Heater': '/m/03qhv5',
#  'Harmonica': '/m/03qjg',
#  'Hamster': '/m/03qrc',
#  'Curtain': '/m/03rszm',
#  'Bed': '/m/03ssj5',
#  'Kettle': '/m/03s_tn',
#  'Fireplace': '/m/03tw93',
#  'Scale': '/m/03txqz',
#  'Drinking straw': '/m/03v5tg',
#  'Insect': '/m/03vt0',
#  'Hair dryer': '/m/03wvsk',
#  'Kitchenware': '/m/03_wxk',
#  'Indoor rower': '/m/03wym',
#  'Invertebrate': '/m/03xxp',
#  'Food processor': '/m/03y6mg',
#  'Bookcase': '/m/03__z0',
#  'Refrigerator': '/m/040b_t',
#  'Wood-burning stove': '/m/04169hn',
#  'Punching bag': '/m/0420v5',
#  'Common fig': '/m/043nyj',
#  'Cocktail shaker': '/m/0440zs',
#  'Jaguar': '/m/0449p',
#  'Golf ball': '/m/044r5d',
#  'Fashion accessory': '/m/0463sg',
#  'Alarm clock': '/m/046dlr',
#  'Filing cabinet': '/m/047j0r',
#  'Artichoke': '/m/047v4b',
#  'Table': '/m/04bcr3',
#  'Tableware': '/m/04brg2',
#  'Kangaroo': '/m/04c0y',
#  'Koala': '/m/04cp_',
#  'Knife': '/m/04ctx',
#  'Bottle': '/m/04dr76w',
#  'Bottle opener': '/m/04f5ws',
#  'Lynx': '/m/04g2r',
#  'Lavender': '/m/04gth',
#  'Lighthouse': '/m/04h7h',
#  'Dumbbell': '/m/04h8sr',
#  'Human head': '/m/04hgtk',
#  'Bowl': '/m/04kkgm',
#  'Humidifier': '/m/04lvq_',
#  'Porch': '/m/04m6gz',
#  'Lizard': '/m/04m9y',
#  'Billiard table': '/m/04p0qw',
#  'Mammal': '/m/04rky',
#  'Mouse': '/m/04rmv',
#  'Motorcycle': '/m/04_sv',
#  'Musical instrument': '/m/04szw',
#  'Swim cap': '/m/04tn4x',
#  'Frying pan': '/m/04v6l4',
#  'Snowplow': '/m/04vv5k',
#  'Bathroom cabinet': '/m/04y4h8h',
#  'Missile': '/m/04ylt',
#  'Bust': '/m/04yqq2',
#  'Man': '/m/04yx4',
#  'Waffle iron': '/m/04z4wx',
#  'Milk': '/m/04zpv',
#  'Ring binder': '/m/04zwwv',
#  'Plate': '/m/050gv4',
#  'Mobile phone': '/m/050k8',
#  'Baked goods': '/m/052lwg6',
#  'Mushroom': '/m/052sf',
#  'Crutch': '/m/05441v',
#  'Pitcher': '/m/054fyh',
#  'Mirror': '/m/054_l',
#  'Lifejacket': '/m/054xkw',
#  'Table tennis racket': '/m/05_5p_0',
#  'Pencil case': '/m/05676x',
#  'Musical keyboard': '/m/057cc',
#  'Scoreboard': '/m/057p5t',
#  'Briefcase': '/m/0584n8',
#  'Kitchen knife': '/m/058qzx',
#  'Nail': '/m/05bm6',
#  'Tennis ball': '/m/05ctyq',
#  'Plastic bag': '/m/05gqfk',
#  'Oboe': '/m/05kms',
#  'Chest of drawers': '/m/05kyg_',
#  'Ostrich': '/m/05n4y',
#  'Piano': '/m/05r5c',
#  'Girl': '/m/05r655',
#  'Plant': '/m/05s2s',
#  'Potato': '/m/05vtc',
#  'Hair spray': '/m/05w9t9',
#  'Sports equipment': '/m/05y5lj',
#  'Pasta': '/m/05z55',
#  'Penguin': '/m/05z6w',
#  'Pumpkin': '/m/05zsy',
#  'Pear': '/m/061_f',
#  'Infant bed': '/m/061hd_',
#  'Polar bear': '/m/0633h',
#  'Mixer': '/m/063rgb',
#  'Cupboard': '/m/0642b4',
#  'Jacuzzi': '/m/065h6l',
#  'Pizza': '/m/0663v',
#  'Digital clock': '/m/06_72j',
#  'Pig': '/m/068zj',
#  'Reptile': '/m/06bt6',
#  'Rifle': '/m/06c54',
#  'Lipstick': '/m/06c7f7',
#  'Skateboard': '/m/06_fw',
#  'Raven': '/m/06j2d',
#  'High heels': '/m/06k2mb',
#  'Red panda': '/m/06l9r',
#  'Rose': '/m/06m11',
#  'Rabbit': '/m/06mf6',
#  'Sculpture': '/m/06msq',
#  'Saxophone': '/m/06ncr',
#  'Shotgun': '/m/06nrc',
#  'Seafood': '/m/06nwz',
#  'Submarine sandwich': '/m/06pcq',
#  'Snowboard': '/m/06__v',
#  'Sword': '/m/06y5r',
#  'Picture frame': '/m/06z37_',
#  'Sushi': '/m/07030',
#  'Loveseat': '/m/0703r8',
#  'Ski': '/m/071p9',
#  'Squirrel': '/m/071qp',
#  'Tripod': '/m/073bxn',
#  'Stethoscope': '/m/073g6',
#  'Submarine': '/m/074d1',
#  'Scorpion': '/m/0755b',
#  'Segway': '/m/076bq',
#  'Training bench': '/m/076lb9',
#  'Snake': '/m/078jl',
#  'Coffee table': '/m/078n6m',
#  'Skyscraper': '/m/079cl',
#  'Sheep': '/m/07bgp',
#  'Television': '/m/07c52',
#  'Trombone': '/m/07c6l',
#  'Tea': '/m/07clx',
#  'Tank': '/m/07cmd',
#  'Taco': '/m/07crc',
#  'Telephone': '/m/07cx4',
#  'Torch': '/m/07dd4',
#  'Tiger': '/m/07dm6',
#  'Strawberry': '/m/07fbm7',
#  'Trumpet': '/m/07gql',
#  'Tree': '/m/07j7r',
#  'Tomato': '/m/07j87',
#  'Train': '/m/07jdr',
#  'Tool': '/m/07k1x',
#  'Picnic basket': '/m/07kng9',
#  'Cooking spray': '/m/07mcwg',
#  'Trousers': '/m/07mhn',
#  'Bowling equipment': '/m/07pj7bq',
#  'Football helmet': '/m/07qxg_',
#  'Truck': '/m/07r04',
#  'Measuring cup': '/m/07v9_z',
#  'Coffeemaker': '/m/07xyvk',
#  'Violin': '/m/07y_7',
#  'Vehicle': '/m/07yv9',
#  'Handbag': '/m/080hkjn',
#  'Paper cutter': '/m/080n7g',
#  'Wine': '/m/081qc',
#  'Weapon': '/m/083kb',
#  'Wheel': '/m/083wq',
#  'Worm': '/m/084hf',
#  'Wok': '/m/084rd',
#  'Whale': '/m/084zz',
#  'Zebra': '/m/0898b',
#  'Auto part': '/m/08dz3q',
#  'Jug': '/m/08hvt4',
#  'Pizza cutter': '/m/08ks85',
#  'Cream': '/m/08p92x',
#  'Monkey': '/m/08pbxl',
#  'Lion': '/m/096mb',
#  'Bread': '/m/09728',
#  'Platter': '/m/099ssp',
#  'Chicken': '/m/09b5t',
#  'Eagle': '/m/09csl',
#  'Helicopter': '/m/09ct_',
#  'Owl': '/m/09d5_',
#  'Duck': '/m/09ddx',
#  'Turtle': '/m/09dzg',
#  'Hippopotamus': '/m/09f20',
#  'Crocodile': '/m/09f_2',
#  'Toilet': '/m/09g1w',
#  'Toilet paper': '/m/09gtd',
#  'Squid': '/m/09gys',
#  'Clothing': '/m/09j2d',
#  'Footwear': '/m/09j5n',
#  'Lemon': '/m/09k_b',
#  'Spider': '/m/09kmb',
#  'Deer': '/m/09kx5',
#  'Frog': '/m/09ld4',
#  'Banana': '/m/09qck',
#  'Rocket': '/m/09rvcxw',
#  'Wine glass': '/m/09tvcd',
#  'Countertop': '/m/0b3fp9',
#  'Tablet computer': '/m/0bh9flk',
#  'Waste container': '/m/0bjyj5',
#  'Swimming pool': '/m/0b_rs',
#  'Dog': '/m/0bt9lr',
#  'Book': '/m/0bt_c3',
#  'Elephant': '/m/0bwd_0j',
#  'Shark': '/m/0by6g',
#  'Candle': '/m/0c06p',
#  'Leopard': '/m/0c29q',
#  'Axe': '/m/0c2jj',
#  'Hand dryer': '/m/0c3m8g',
#  'Soap dispenser': '/m/0c3mkw',
#  'Porcupine': '/m/0c568',
#  'Flower': '/m/0c9ph5',
#  'Canary': '/m/0ccs93',
#  'Cheetah': '/m/0cd4d',
#  'Palm tree': '/m/0cdl1',
#  'Hamburger': '/m/0cdn1',
#  'Maple': '/m/0cffdh',
#  'Building': '/m/0cgh4',
#  'Fish': '/m/0ch_cf',
#  'Lobster': '/m/0cjq5',
#  'Asparagus': '/m/0cjs7',
#  'Furniture': '/m/0c_jw',
#  'Hedgehog': '/m/0cl4p',
#  'Airplane': '/m/0cmf2',
#  'Spoon': '/m/0cmx8',
#  'Otter': '/m/0cn6p',
#  'Bull': '/m/0cnyhnx',
#  'Oyster': '/m/0_cp5',
#  'Horizontal bar': '/m/0cqn2',
#  'Convenience store': '/m/0crjs',
#  'Bomb': '/m/0ct4f',
#  'Bench': '/m/0cvnqh',
#  'Ice cream': '/m/0cxn2',
#  'Caterpillar': '/m/0cydv',
#  'Butterfly': '/m/0cyf8',
#  'Parachute': '/m/0cyfs',
#  'Orange': '/m/0cyhj_',
#  'Antelope': '/m/0czz2',
#  'Beaker': '/m/0d20w4',
#  'Moths and butterflies': '/m/0d_2m',
#  'Window': '/m/0d4v4',
#  'Closet': '/m/0d4w1',
#  'Castle': '/m/0d5gx',
#  'Jellyfish': '/m/0d8zb',
#  'Goose': '/m/0dbvp',
#  'Mule': '/m/0dbzx',
#  'Swan': '/m/0dftk',
#  'Peach': '/m/0dj6p',
#  'Coconut': '/m/0djtd',
#  'Seat belt': '/m/0dkzw',
#  'Raccoon': '/m/0dq75',
#  'Chisel': '/m/0_dqb',
#  'Fork': '/m/0dt3t',
#  'Lamp': '/m/0dtln',
#  'Camera': '/m/0dv5r',
#  'Squash': '/m/0dv77',
#  'Racket': '/m/0dv9c',
#  'Human face': '/m/0dzct',
#  'Human arm': '/m/0dzf4',
#  'Vegetable': '/m/0f4s2w',
#  'Diaper': '/m/0f571',
#  'Unicycle': '/m/0f6nr',
#  'Falcon': '/m/0f6wt',
#  'Chime': '/m/0f8s22',
#  'Snail': '/m/0f9_l',
#  'Shellfish': '/m/0fbdv',
#  'Cabbage': '/m/0fbw6',
#  'Carrot': '/m/0fj52s',
#  'Mango': '/m/0fldg',
#  'Jeans': '/m/0fly7',
#  'Flowerpot': '/m/0fm3zh',
#  'Pineapple': '/m/0fp6w',
#  'Drawer': '/m/0fqfqc',
#  'Stool': '/m/0fqt361',
#  'Envelope': '/m/0frqm',
#  'Cake': '/m/0fszt',
#  'Dragonfly': '/m/0ft9s',
#  'Sunflower': '/m/0ftb8',
#  'Microwave oven': '/m/0fx9l',
#  'Honeycomb': '/m/0fz0h',
#  'Marine mammal': '/m/0gd2v',
#  'Sea lion': '/m/0gd36',
#  'Ladybug': '/m/0gj37',
#  'Shelf': '/m/0gjbg72',
#  'Watch': '/m/0gjkl',
#  'Candy': '/m/0gm28',
#  'Salad': '/m/0grw1',
#  'Parrot': '/m/0gv1x',
#  'Handgun': '/m/0gxl3',
#  'Sparrow': '/m/0h23m',
#  'Van': '/m/0h2r6',
#  'Grinder': '/m/0h8jyh6',
#  'Spice rack': '/m/0h8kx63',
#  'Light bulb': '/m/0h8l4fh',
#  'Corded phone': '/m/0h8lkj8',
#  'Sports uniform': '/m/0h8mhzd',
#  'Tennis racket': '/m/0h8my_4',
#  'Wall clock': '/m/0h8mzrc',
#  'Serving tray': '/m/0h8n27j',
#  'Kitchen & dining room table': '/m/0h8n5zk',
#  'Dog bed': '/m/0h8n6f9',
#  'Cake stand': '/m/0h8n6ft',
#  'Cat furniture': '/m/0h8nm9j',
#  'Bathroom accessory': '/m/0h8nr_l',
#  'Facial tissue holder': '/m/0h8nsvg',
#  'Pressure cooker': '/m/0h8ntjv',
#  'Kitchen appliance': '/m/0h99cwc',
#  'Tire': '/m/0h9mv',
#  'Ruler': '/m/0hdln',
#  'Luggage and bags': '/m/0hf58v5',
#  'Microphone': '/m/0hg7b',
#  'Broccoli': '/m/0hkxq',
#  'Umbrella': '/m/0hnnb',
#  'Pastry': '/m/0hnyx',
#  'Grapefruit': '/m/0hqkz',
#  'Band-aid': '/m/0j496',
#  'Animal': '/m/0jbk',
#  'Bell pepper': '/m/0jg57',
#  'Turkey': '/m/0jly1',
#  'Lily': '/m/0jqgx',
#  'Pomegranate': '/m/0jwn_',
#  'Doughnut': '/m/0jy4k',
#  'Glasses': '/m/0jyfg',
#  'Human nose': '/m/0k0pj',
#  'Pen': '/m/0k1tl',
#  'Ant': '/m/0_k2',
#  'Car': '/m/0k4j',
#  'Aircraft': '/m/0k5j',
#  'Human hand': '/m/0k65p',
#  'Skunk': '/m/0km7z',
#  'Teddy bear': '/m/0kmg4',
#  'Watermelon': '/m/0kpqd',
#  'Cantaloupe': '/m/0kpt_',
#  'Dishwasher': '/m/0ky7b',
#  'Flute': '/m/0l14j_',
#  'Balance beam': '/m/0l3ms',
#  'Sandwich': '/m/0l515',
#  'Shrimp': '/m/0ll1f78',
#  'Sewing machine': '/m/0llzx',
#  'Binoculars': '/m/0lt4_',
#  'Rays and skates': '/m/0m53l',
#  'Ipod': '/m/0mcx2',
#  'Accordion': '/m/0mkg',
#  'Willow': '/m/0mw_6',
#  'Crab': '/m/0n28_',
#  'Crown': '/m/0nl46',
#  'Seahorse': '/m/0nybt',
#  'Perfume': '/m/0p833',
#  'Alpaca': '/m/0pcr',
#  'Taxi': '/m/0pg52',
#  'Canoe': '/m/0ph39',
#  'Remote control': '/m/0qjjc',
#  'Wheelchair': '/m/0qmmr',
#  'Rugby ball': '/m/0wdt60w',
#  'Armadillo': '/m/0xfy',
#  'Maracas': '/m/0xzly',
#  'Helmet': '/m/0zvk5'}
